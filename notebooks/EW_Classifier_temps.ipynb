# %% [markdown]
# <a href="https://colab.research.google.com/github/robinkiplangat/dexter_dashboard/blob/main/notebooks/EW_Classifier_temps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Set up

# %%
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Work from Project Folder
# %cd '/content/drive/MyDrive/ColabNotebooks/EleWa'
# Out:
# /content/drive/MyDrive/ColabNotebooks/EleWa

# %% [markdown]
# # Election Watch Classification Pipeline
# Categorize tweets based on the provided election-related narratives. The pipeline should take a tweet and the narrative descriptions as input and output the predicted narrative categories.

# %% [markdown]
# ## Install necessary libraries
#
# Required libraries, such as `transformers` and `torch`.

# %%
# !pip install -U transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting torch
#   Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch)
#   Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch) (75.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 38.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 34.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 35.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 7.0 MB/s eta 0:00:00
# Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 7.5 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 73.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124

# %% [markdown]
# ## Load the model and tokenizer
#
# ### Subtask:
# Load a pre-trained language model suitable for text classification and its corresponding tokenizer.

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     707         try:
# --> 708             return getattribute_from_module(transformers_module, attr)
#     709         except ValueError:
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     711     else:
# --> 712         raise ValueError(f"Could not find {attr} in {transformers_module}!")
#     713
#
# ValueError: Could not find DistilBertForSequenceClassification in <module 'transformers' from '/usr/local/lib/python3.11/dist-packages/transformers/__init__.py'>!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-3388149202> in <cell line: 0>()
#       3 model_name = "distilbert-base-uncased"
#       4 tokenizer = AutoTokenizer.from_pretrained(model_name)
# ----> 5 model = AutoModelForSequenceClassification.from_pretrained(model_name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     566             )
#     567         elif type(config) in cls._model_mapping.keys():
# --> 568             model_class = _get_model_class(config, cls._model_mapping)
#     569             if model_class.config_class == config.sub_configs.get("text_config", None):
#     570                 config = config.get_text_config()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in _get_model_class(config, model_mapping)
#     386
#     387 def _get_model_class(config, model_mapping):
# --> 388     supported_models = model_mapping[type(config)]
#     389     if not isinstance(supported_models, (list, tuple)):
#     390         return supported_models
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in __getitem__(self, key)
#     772         if model_type in self._model_mapping:
#     773             model_name = self._model_mapping[model_type]
# --> 774             return self._load_attr_from_module(model_type, model_name)
#     775
#     776         # Maybe there was several model types associated with this config.
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#     786         if module_name not in self._modules:
#     787             self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 788         return getattribute_from_module(self._modules[module_name], attr)
#     789
#     790     def keys(self):
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     708             return getattribute_from_module(transformers_module, attr)
#     709         except ValueError:
# --> 710             raise ValueError(f"Could not find {attr} neither in {module} nor in {transformers_module}!")
#     711     else:
#     712         raise ValueError(f"Could not find {attr} in {transformers_module}!")
#
# ValueError: Could not find DistilBertForSequenceClassification neither in <module 'transformers.models.distilbert' from '/usr/local/lib/python3.11/dist-packages/transformers/models/distilbert/__init__.py'> nor in <module 'transformers' from '/usr/local/lib/python3.11/dist-packages/transformers/__init__.py'>!

# %% [markdown]
# ## Load Narratives
#
# Load the narratives from the provided CSV file.

# %% [markdown]
# **Reasoning**:
# Load the data from the specified CSV file into a pandas DataFrame.

# %%
import pandas as pd

narratives_df = pd.read_csv("Meta_narratives_in_African_elections.csv")
display(narratives_df)
# Out:
#                           Meta-Narrative  \
# 0  Foreign Interference / Neocolonialism
# 1      Rigged Elections / Stolen Mandate
# 2           Tech Manipulation Narratives
# 3        Ethnic / Religious Polarisation
# 4            Coup or Military Narratives
# 5        Divine / Prophetic Endorsements
# 6            Fake Polls and Media Clones
# 7   Populist “Clean Outsider” Narratives
# 8        Youth Disenfranchisement Claims
#
#                                          Description  \
# 0  Claims that Western nations manipulate electio...
# 1  Accusations of widespread rigging by incumbent...
# 2  Suggests that biometric systems or voting tech...
# 3  Claims that certain groups will be targeted, m...
# 4  Elections framed as a front for military contr...
# 5  Candidates are presented as “chosen by God” or...
# 6  Spread of false public opinion data or cloned ...
# 7  Frame outsider candidates as incorruptible, sa...
# 8  Narratives suggesting youth are being suppress...
#
#                                         Tactics Used  \
# 0  Fake reports, NGO conspiracies, doctored forei...
# 1  Fake tally sheets, videos of “ballot stuffing,...
# 2  Fake tech “hacks,” rumours about foreign-manuf...
# 3  Deepfakes, edited quotes, emotional religious ...
# 4  Leaked documents, soldier testimonies, “anonym...
# 5  Viral prophecy videos, fake endorsements from ...
# 6  Polls with no source, doctored media logos, im...
# 7  Exaggerated life stories, viral infographics, ...
# 8  Claims of voter roll issues at campuses, “yout...
#
#                         Common Locations  \
# 0     Mali, Burkina Faso, Senegal, Niger
# 1           Nigeria, Ghana, Sierra Leone
# 2                  Nigeria (BVAS), Kenya
# 3         Nigeria, Côte d’Ivoire, Guinea
# 4             Mali, Burkina Faso, Guinea
# 5                         Nigeria, Ghana
# 6                Kenya, Nigeria, Senegal
# 7  Senegal (Pastef), Nigeria (Obidients)
# 8                Nigeria, Ghana, Senegal
#
#                                       Purpose/Effect
# 0  Delegitimise pro-West candidates; justify junt...
# 1  Undermine confidence in the electoral process;...
# 2     Undermine trust in digitised election systems.
# 3  Mobilise identity-based voting; intimidate or ...
# 4  Discredit elections under junta rule or imply ...
# 5  Exploit religious beliefs for legitimacy or su...
# 6  Shape public perception; suppress opposition m...
# 7  Fuel cult-like devotion; position candidate as...
# 8  Galvanise youth movements; accuse system of ag...

# %% [markdown]
# ###  Prepare the narratives
#
# Format the narratives from the DataFrame into a suitable structure for the model to understand.

# %%
formatted_narratives = []
for index, row in narratives_df.iterrows():
    narrative_name = row['Meta-Narrative']
    description = row['Description']
    formatted_narratives.append(f"[CLS] {narrative_name}: {description} [SEP]")

print(formatted_narratives)
# Out:
# ['[CLS] Foreign Interference / Neocolonialism: Claims that Western nations manipulate elections to install puppet leaders. [SEP]', '[CLS] Rigged Elections / Stolen Mandate: Accusations of widespread rigging by incumbents or dominant ethnic groups. [SEP]', '[CLS] Tech Manipulation Narratives: Suggests that biometric systems or voting tech are tools for fraud. [SEP]', '[CLS] Ethnic / Religious Polarisation: Claims that certain groups will be targeted, marginalised, or favoured after elections. [SEP]', '[CLS] Coup or Military Narratives: Elections framed as a front for military control or impending coups. [SEP]', '[CLS] Divine / Prophetic Endorsements: Candidates are presented as “chosen by God” or predicted to win by religious figures. [SEP]', '[CLS] Fake Polls and Media Clones: Spread of false public opinion data or cloned news sites that misreport election trends. [SEP]', '[CLS] Populist “Clean Outsider” Narratives: Frame outsider candidates as incorruptible, saviour figures. [SEP]', '[CLS] Youth Disenfranchisement Claims: Narratives suggesting youth are being suppressed or manipulated. [SEP]']

# %% [markdown]
# ## Load the dataset
#
# Load the provided Excel file containing tweets into a pandas DataFrame.

# %%
excel_file_path = "Robin_Nigeria_Election_tweets_dataset.xlsx"

# Load specific sheets from the Excel file
excel_data = pd.ExcelFile(excel_file_path)
tweets_df = excel_data.parse('tweets')
retweets_df = excel_data.parse('retweets')
accounts_df = excel_data.parse('accounts')

display(tweets_df.head(3))
display(retweets_df.head(3))
display(accounts_df.head(3))
# Out:
#               Tweet ID Twitter Users Retweet username Day of Time  Retweets  \
# 0  1579533598625240064       _weyimi         davosala  2022-10-10     10639
# 1  1578291198951030016       imp213x         davosala  2022-10-07      7769
# 2  1575938681676110080    urchilla01          GovWike  2022-09-30      5449
#
#     Party                                              Tweet
# 0  Labour  RT @davosala: @PeterObi on transit. As a Keke ...
# 1  Labour  RT @davosala: @PeterObi on transit. As a Keke ...
# 2     APC  RT @GovWike: It was nice hosting my brother @P...
#   Twitter Users Retweet username
# 0       _weyimi         davosala
# 1       imp213x         davosala
# 2    urchilla01          GovWike
#   Twitter Users  Followers Full name Location Profile Image Party  \
# 0      davosala          1       NaN      NaN           NaN   NaN
# 1       GovWike          1       NaN      NaN           NaN   NaN
# 2      NgLabour          1       NaN      NaN           NaN   NaN
#
#                                                Tweet
# 0  RT @davosala: @PeterObi on transit. As a Keke ...
# 1  RT @GovWike: It was nice hosting my brother @P...
# 2  RT @NgLabour: Your PVC is your Power. Have you...

# %% [markdown]
# ## Preprocess the text data
#
# Clean and preprocess the text data in the dataset (e.g., handle missing values, remove special characters, normalize text).

# %%
# 1. Inspect the tweets_df DataFrame to identify the column containing the text data
print(tweets_df.info())

# Identify the text column - based on the head output, it seems to be 'Tweet'
text_column = 'Tweet'

# 2. Handle any missing values in the text column
# Option 1: Remove rows with missing text
# tweets_df.dropna(subset=[text_column], inplace=True)

# Option 2: Replace missing values with an empty string
tweets_df[text_column].fillna('', inplace=True)

print(f"\nMissing values in '{text_column}' after handling: {tweets_df[text_column].isnull().sum()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tweet ID          69 non-null     int64
#  1   Twitter Users     69 non-null     object
#  2   Retweet username  69 non-null     object
#  3   Day of Time       69 non-null     datetime64[ns]
#  4   Retweets          69 non-null     int64
#  5   Party             69 non-null     object
#  6   Tweet             69 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 3.9+ KB
# None
#
# Missing values in 'Tweet' after handling: 0
# <ipython-input-19-3837103755>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tweets_df[text_column].fillna('', inplace=True)

# %% [markdown]
# **Reasoning**:
# Define a text cleaning function and apply it to the text column of the DataFrame to create a new cleaned text column.

# %%
import re

def clean_text(text):
    """
    Cleans the input text by removing URLs, mentions, hashtags, punctuation,
    and converting text to lowercase.
    """
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove mentions (@...)
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags (#...)
    text = re.sub(r'#\w+', '', text)
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

# 4. Apply the cleaning function to the text column
tweets_df['cleanTweet'] = tweets_df[text_column].apply(clean_text)

# Display the original and cleaned tweets
display(tweets_df[[text_column, 'cleanTweet']].head())
# Out:
#                                                Tweet  \
# 0  RT @davosala: @PeterObi on transit. As a Keke ...
# 1  RT @davosala: @PeterObi on transit. As a Keke ...
# 2  RT @GovWike: It was nice hosting my brother @P...
# 3  RT @NgLabour: Your PVC is your Power. Have you...
# 4  RT @rosenthal_jon: Oh dear, it is never a good...
#
#                                           cleanTweet
# 0  rt   on transit as a keke rider i carry more t...
# 1  rt   on transit as a keke rider i carry more t...
# 2    rt  it was nice hosting my brother  once again
# 3  rt  your pvc is your power have you gotten it ...
# 4  rt  oh dear it is never a good sign in a presi...

# %%
# tweets_df.head(2)

# %% [markdown]
# ## Extract actors (named entity recognition)
#
# Use a pre-trained model or library to identify and extract named entities (potential actors) from the text data.

# %%
from transformers import pipeline

# Create a named entity recognition (NER) pipeline
# Using a suitable pre-trained model (e.g., "dslim/bert-base-NER")
ner_pipeline = pipeline("ner", model="dslim/bert-base-NER", grouped_entities=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-2622684873> in <cell line: 0>()
# ----> 1 from transformers import pipeline
#       2
#       3 # Create a named entity recognition (NER) pipeline
#       4 # Using a suitable pre-trained model (e.g., "dslim/bert-base-NER")
#       5 ner_pipeline = pipeline("ner", model="dslim/bert-base-NER", grouped_entities=True)
#
# ImportError: cannot import name 'pipeline' from 'transformers' (/usr/local/lib/python3.11/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def extract_entities(text):
    """
    Extracts named entities from the input text using the NER pipeline.
    """
    if pd.isna(text):
        return []
    entities = ner_pipeline(text)
    # Extract only the entity text and type
    extracted_list = [{'entity': entity['word'], 'type': entity['entity_group']} for entity in entities]
    return extracted_list

# Apply the function to the 'Cleaned Tweet' column
tweets_df['Extracted_Actors'] = tweets_df['cleanTweet'].apply(extract_entities)

# Display the first few rows with relevant columns
display(tweets_df[['cleanTweet', 'Extracted_Actors']].head(3))

# %%
tweets_df.Extracted_Actors[67]
# Out:
# [{'entity': 'se', 'type': 'PER'}]

# %% [markdown]
# ## Classify narratives
#
# Apply the existing narrative classification pipeline to each tweet/post in the dataset to identify the relevant narratives.

# %% [markdown]
# Iterate through the DataFrame, classify each tweet using the defined function, and store the results in a new column.

# %%
tweets_df['Predicted_Narratives'] = tweets_df['cleanTweet'].apply(
    lambda tweet: classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model)
)

display(tweets_df[['cleanTweet', 'Predicted_Narratives']].head())
# Out:
#                                           cleanTweet  \
# 0  rt   on transit as a keke rider i carry more t...
# 1  rt   on transit as a keke rider i carry more t...
# 2    rt  it was nice hosting my brother  once again
# 3  rt  your pvc is your power have you gotten it ...
# 4  rt  oh dear it is never a good sign in a presi...
#
#                                 Predicted_Narratives
# 0                  [Divine / Prophetic Endorsements]
# 1                  [Divine / Prophetic Endorsements]
# 2  [Rigged Elections / Stolen Mandate, Divine / P...
# 3  [Foreign Interference / Neocolonialism, Rigged...
# 4  [Foreign Interference / Neocolonialism, Rigged...

# %% [markdown]
# ## Create Network Graph
#
# Create a network graph using `networkx` from the extracted connections.

# %% [markdown]
# **Reasoning**:
# Import the `networkx` library and iterate through the 'Extracted Connections' column of the DataFrame to add nodes and edges to a new graph.

# %%
import networkx as nx

# Create an empty graph
G = nx.Graph()

# Iterate through each tweet's connections and add to the graph
for index, row in tweets_df.iterrows():
    connections = row['ExtractedConnections']
    for connection in connections:
        source = connection['source']
        target = connection['target']
        connection_type = connection['type']

        # Add nodes (Actors, Narratives, Timelines)
        G.add_node(source, type='unknown') # We can refine node types later if needed
        G.add_node(target, type='unknown') # We can refine node types later if needed

        # Add edges (connections) with the type as an attribute
        G.add_edge(source, target, type=connection_type)

print(f"Number of nodes in the graph: {G.number_of_nodes()}")
print(f"Number of edges in the graph: {G.number_of_edges()}")

# %%
import torch
import pandas as pd
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import re
from collections import defaultdict

# Load the narratives from the CSV and format them
narratives_df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/EleWa/Meta_narratives_in_African_elections.csv")
formatted_narratives = []
for index, row in narratives_df.iterrows():
    narrative_name = row['Meta-Narrative']
    description = row['Description']
    formatted_narratives.append(f"[CLS] {narrative_name}: {description} [SEP]")

# Re-load the model and tokenizer for narrative classification
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

def classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model):
    """
    Classifies a tweet based on provided election-related narratives.

    Args:
        tweet: A string representing the tweet.
        formatted_narratives: A list of formatted narrative strings.
        tokenizer: The loaded tokenizer.
        model: The loaded pre-trained model.

    Returns:
        A list of predicted narrative categories.
    """
    predicted_categories = []
    for narrative in formatted_narratives:
        # Combine the tweet and narrative for the model
        combined_input = f"[CLS] {tweet} [SEP] {narrative}"

        # Tokenize the combined input
        inputs = tokenizer(combined_input, return_tensors="pt", padding=True, truncation=True, max_length=512)

        # Get model predictions
        with torch.no_grad():
            outputs = model(**inputs)

        # Apply softmax to get probabilities
        probabilities = torch.softmax(outputs.logits, dim=1)

        # Assuming a binary classification output (e.g., [probability of not relevant, probability of relevant])
        # We are interested in the probability of the second class (relevant)
        relevance_probability = probabilities[:, 1].item()

        # Determine if the narrative is predicted for the tweet based on a threshold
        threshold = 0.5  # Example threshold
        if relevance_probability > threshold:
            # Extract the narrative name from the formatted string
            narrative_name = narrative.replace("[CLS] ", "").split(":")[0]
            predicted_categories.append(narrative_name.strip())

    return predicted_categories

# Apply the narrative classification function to the 'Cleaned Tweet' column
# Ensure 'Cleaned Tweet' column exists by re-cleaning if necessary
if 'Cleaned Tweet' not in tweets_df.columns:
     def clean_text(text):
        if pd.isna(text):
            return ""
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'@\w+', '', text)
        text = re.sub(r'#\w+', '', text)
        text = re.sub(r'[^\w\s]', '', text)
        text = text.lower()
        return text
     tweets_df['Cleaned Tweet'] = tweets_df['Tweet'].apply(clean_text)

tweets_df['Predicted Narratives'] = tweets_df['Cleaned Tweet'].apply(
    lambda tweet: classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model)
)

# Now proceed with the temporal analysis
# Initialize a dictionary to store narrative counts per day
narrative_daily_counts = defaultdict(lambda: defaultdict(int))

# Iterate through each tweet
for index, row in tweets_df.iterrows():
    tweet_date = row['Day of Time'].date() # Extract date
    predicted_narratives = row['Predicted Narratives']

    # For each predicted narrative in the tweet, increment the count for that date
    for narrative in predicted_narratives:
        narrative_daily_counts[narrative][tweet_date] += 1

# Convert the nested dictionary to a pandas DataFrame for easier analysis
narrative_temporal_df = pd.DataFrame.from_dict(narrative_daily_counts, orient='index').transpose().fillna(0)

# Sort by date
narrative_temporal_df.sort_index(inplace=True)

# Analyze for peaks (periods of increased discussion)
print("Narrative Temporal Analysis - Peaks:")
for narrative in narrative_temporal_df.columns:
    if not narrative_temporal_df[narrative].empty:
        max_count_date = narrative_temporal_df[narrative].idxmax()
        max_count = narrative_temporal_df[narrative].max()
        if max_count > 0: # Only print if there was activity
            print(f"- '{narrative}': Peak activity of {int(max_count)} occurrences on {max_count_date.strftime('%Y-%m-%d')}")
        else:
             print(f"- '{narrative}': No activity recorded.")
    else:
        print(f"- '{narrative}': No activity recorded.")


# Analyze for emergence dates (first occurrence)
print("\nNarrative Temporal Analysis - Emergence Dates:")
for narrative in narrative_temporal_df.columns:
     if not narrative_temporal_df[narrative].empty:
        # Find the first date where the count is greater than 0
        emergence_date = narrative_temporal_df[narrative][narrative_temporal_df[narrative] > 0].index.min()
        if pd.notna(emergence_date):
            print(f"- '{narrative}': First occurrence on {emergence_date.strftime('%Y-%m-%d')}")
        else:
            print(f"- '{narrative}': No occurrence recorded.")
     else:
        print(f"- '{narrative}': No occurrence recorded.")


# Display the narrative temporal DataFrame
print("\nNarrative Temporal DataFrame (Daily Counts):")
display(narrative_temporal_df)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Narrative Temporal Analysis - Peaks:
# - 'Foreign Interference / Neocolonialism': Peak activity of 11 occurrences on 2022-09-30
# - 'Rigged Elections / Stolen Mandate': Peak activity of 11 occurrences on 2022-09-30
# - 'Tech Manipulation Narratives': Peak activity of 11 occurrences on 2022-09-30
# - 'Ethnic / Religious Polarisation': Peak activity of 11 occurrences on 2022-09-30
# - 'Coup or Military Narratives': Peak activity of 11 occurrences on 2022-09-30
# - 'Divine / Prophetic Endorsements': Peak activity of 11 occurrences on 2022-09-30
# - 'Fake Polls and Media Clones': Peak activity of 11 occurrences on 2022-09-30
# - 'Populist “Clean Outsider” Narratives': Peak activity of 11 occurrences on 2022-09-30
# - 'Youth Disenfranchisement Claims': Peak activity of 11 occurrences on 2022-09-30
#
# Narrative Temporal Analysis - Emergence Dates:
# - 'Foreign Interference / Neocolonialism': First occurrence on 2022-09-30
# - 'Rigged Elections / Stolen Mandate': First occurrence on 2022-09-30
# - 'Tech Manipulation Narratives': First occurrence on 2022-09-30
# - 'Ethnic / Religious Polarisation': First occurrence on 2022-09-30
# - 'Coup or Military Narratives': First occurrence on 2022-09-30
# - 'Divine / Prophetic Endorsements': First occurrence on 2022-09-30
# - 'Fake Polls and Media Clones': First occurrence on 2022-09-30
# - 'Populist “Clean Outsider” Narratives': First occurrence on 2022-09-30
# - 'Youth Disenfranchisement Claims': First occurrence on 2022-09-30
#
# Narrative Temporal DataFrame (Daily Counts):
#             Foreign Interference / Neocolonialism  \
# 2022-09-30                                     11
# 2022-10-01                                      8
# 2022-10-02                                      2
# 2022-10-03                                      5
# 2022-10-04                                      4
# 2022-10-05                                      2
# 2022-10-06                                      4
# 2022-10-07                                      1
# 2022-10-08                                      5
# 2022-10-09                                      3
# 2022-10-10                                      8
# 2022-10-11                                      5
# 2022-10-12                                      8
# 2022-10-13                                      1
# 2022-10-14                                      1
# 2022-10-15                                      1
#
#             Rigged Elections / Stolen Mandate  Tech Manipulation Narratives  \
# 2022-09-30                                 11                            11
# 2022-10-01                                  8                             8
# 2022-10-02                                  2                             2
# 2022-10-03                                  5                             5
# 2022-10-04                                  4                             4
# 2022-10-05                                  2                             2
# 2022-10-06                                  4                             4
# 2022-10-07                                  1                             1
# 2022-10-08                                  5                             5
# 2022-10-09                                  3                             3
# 2022-10-10                                  8                             8
# 2022-10-11                                  5                             5
# 2022-10-12                                  8                             8
# 2022-10-13                                  1                             1
# 2022-10-14                                  1                             1
# 2022-10-15                                  1                             1
#
#             Ethnic / Religious Polarisation  Coup or Military Narratives  \
# 2022-09-30                               11                           11
# 2022-10-01                                8                            8
# 2022-10-02                                2                            2
# 2022-10-03                                5                            5
# 2022-10-04                                4                            4
# 2022-10-05                                2                            2
# 2022-10-06                                4                            4
# 2022-10-07                                1                            1
# 2022-10-08                                5                            5
# 2022-10-09                                3                            3
# 2022-10-10                                8                            8
# 2022-10-11                                5                            5
# 2022-10-12                                8                            8
# 2022-10-13                                1                            1
# 2022-10-14                                1                            1
# 2022-10-15                                1                            1
#
#             Divine / Prophetic Endorsements  Fake Polls and Media Clones  \
# 2022-09-30                               11                           11
# 2022-10-01                                8                            8
# 2022-10-02                                2                            2
# 2022-10-03                                5                            5
# 2022-10-04                                4                            4
# 2022-10-05                                2                            2
# 2022-10-06                                4                            4
# 2022-10-07                                1                            1
# 2022-10-08                                5                            5
# 2022-10-09                                3                            3
# 2022-10-10                                8                            8
# 2022-10-11                                5                            5
# 2022-10-12                                8                            8
# 2022-10-13                                1                            1
# 2022-10-14                                1                            1
# 2022-10-15                                1                            1
#
#             Populist “Clean Outsider” Narratives  \
# 2022-09-30                                    11
# 2022-10-01                                     8
# 2022-10-02                                     2
# 2022-10-03                                     5
# 2022-10-04                                     4
# 2022-10-05                                     2
# 2022-10-06                                     4
# 2022-10-07                                     1
# 2022-10-08                                     5
# 2022-10-09                                     3
# 2022-10-10                                     8
# 2022-10-11                                     5
# 2022-10-12                                     8
# 2022-10-13                                     1
# 2022-10-14                                     1
# 2022-10-15                                     1
#
#             Youth Disenfranchisement Claims
# 2022-09-30                               11
# 2022-10-01                                8
# 2022-10-02                                2
# 2022-10-03                                5
# 2022-10-04                                4
# 2022-10-05                                2
# 2022-10-06                                4
# 2022-10-07                                1
# 2022-10-08                                5
# 2022-10-09                                3
# 2022-10-10                                8
# 2022-10-11                                5
# 2022-10-12                                8
# 2022-10-13                                1
# 2022-10-14                                1
# 2022-10-15                                1

# %% [markdown]
# ## Timelines, Insights and Analysis
#
# Analyze patterns of the extracted narratives to identify periods of increased discussion or the emergence of new narratives.

# %%
formatted_narratives
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1028127859> in <cell line: 0>()
# ----> 1 formatted_narratives
#
# NameError: name 'formatted_narratives' is not defined

# %%
import torch
import pandas as pd
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import re
from collections import defaultdict

# # 1. Re-load the narrative definitions from the CSV file and format them
# try:
#     narratives_df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/EleWa/Meta_narratives_in_African_elections.csv")
# except FileNotFoundError:
#     print("Error: Narrative CSV file not found. Please ensure 'Meta_narratives_in_African_elections.csv' is in the specified path.")
#     narratives_df = pd.DataFrame() # Create an empty DataFrame to avoid further errors

# formatted_narratives = []
# if not narratives_df.empty:
#     for index, row in narratives_df.iterrows():
#         narrative_name = row['Meta-Narrative']
#         description = row['Description']
#         formatted_narratives.append(f"[CLS] {narrative_name}: {description} [SEP]")
# else:
#     print("Cannot format narratives as the narratives DataFrame is empty.")

# 2. Re-load the model and tokenizer for narrative classification
model_name = "distilbert-base-uncased"
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
except Exception as e:
    print(f"Error loading model or tokenizer: {e}")
    tokenizer = None
    model = None


# 3. Define the classify_tweet_narratives function
def classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model):
    """
    Classifies a tweet based on provided election-related narratives.

    Args:
        tweet: A string representing the tweet.
        formatted_narratives: A list of formatted narrative strings.
        tokenizer: The loaded tokenizer.
        model: The loaded pre-trained model.

    Returns:
        A list of predicted narrative categories.
    """
    if tokenizer is None or model is None or not formatted_narratives:
        return []

    predicted_categories = []
    for narrative in formatted_narratives:
        # Combine the tweet and narrative for the model
        combined_input = f"[CLS] {tweet} [SEP] {narrative}"

        # Tokenize the combined input
        inputs = tokenizer(combined_input, return_tensors="pt", padding=True, truncation=True, max_length=512)

        # Get model predictions
        with torch.no_grad():
            try:
                outputs = model(**inputs)
            except Exception as e:
                print(f"Error during model prediction: {e}")
                continue


        # Apply softmax to get probabilities
        probabilities = torch.softmax(outputs.logits, dim=1)

        # Assuming a binary classification output (e.g., [probability of not relevant, probability of relevant])
        # We are interested in the probability of the second class (relevant)
        relevance_probability = probabilities[:, 1].item()

        # Determine if the narrative is predicted for the tweet based on a threshold
        threshold = 0.5  # Example threshold
        if relevance_probability > threshold:
            # Extract the narrative name from the formatted string
            narrative_name = narrative.replace("[CLS] ", "").split(":")[0]
            predicted_categories.append(narrative_name.strip())

    return predicted_categories

# 4. Ensure the 'cleanTweet' column exists by re-cleaning if necessary
if 'cleanTweet' not in tweets_df.columns:
     def clean_text(text):
        if pd.isna(text):
            return ""
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'@\w+', '', text)
        text = re.sub(r'#\w+', '', text)
        text = re.sub(r'[^\w\s]', '', text)
        text = text.lower()
        return text
     tweets_df['cleanTweet'] = tweets_df['Tweet'].apply(clean_text)

# 5. Apply the narrative classification function to the 'Cleaned Tweet' column
if tokenizer is not None and model is not None and not formatted_narratives:
    tweets_df['Predicted_Narratives'] = tweets_df['cleanTweet'].apply(
        lambda tweet: classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model)
    )
else:
     print("Skipping narrative classification due to previous errors or empty narratives.")
     tweets_df['Predicted_Narratives'] = [[]] * len(tweets_df)


# 6. Initialize a dictionary to store narrative counts per day
narrative_daily_counts = defaultdict(lambda: defaultdict(int))

# Iterate through each tweet
for index, row in tweets_df.iterrows():
    tweet_date = row['Day of Time'].date() # Extract date
    predicted_narratives = row['Predicted_Narratives']

    # For each predicted narrative in the tweet, increment the count for that date
    for narrative in predicted_narratives:
        narrative_daily_counts[narrative][tweet_date] += 1

# 7. Convert the nested dictionary to a pandas DataFrame for easier analysis
narrative_temp_df = pd.DataFrame.from_dict(narrative_daily_counts, orient='index').transpose().fillna(0)

# 8. Sort by date
narrative_temp_df.sort_index(inplace=True)

# 9. Analyze for peaks (periods of increased discussion)
print("Narrative Temp Analysis - Peaks:")
for narrative in narrative_temp_df.columns:
    if not narrative_temp_df[narrative].empty and narrative_temp_df[narrative].sum() > 0:
        max_count_date = narrative_temp_df[narrative].idxmax()
        max_count = narrative_temp_df[narrative].max()
        print(f"- '{narrative}': Peak activity of {int(max_count)} occurrences on {max_count_date.strftime('%Y-%m-%d')}")
    else:
        print(f"- '{narrative}': No activity recorded.")


# 10. Analyze for emergence dates (first occurrence)
print("\nNarrative Temporal Analysis - Emergence Dates:")
for narrative in narrative_temp_df.columns:
     if not narrative_temp_df[narrative].empty and narrative_temp_df[narrative].sum() > 0:
        # Find the first date where the count is greater than 0
        emergence_date = narrative_temp_df[narrative][narrative_temp_df[narrative] > 0].index.min()
        if pd.notna(emergence_date):
            print(f"- '{narrative}': First occurrence on {emergence_date.strftime('%Y-%m-%d')}")
        else:
            print(f"- '{narrative}': No occurrence recorded.")
     else:
        print(f"- '{narrative}': No occurrence recorded.")


# 11. Display the narrative temporal DataFrame
print("\nNarrative Temp DataFrame (Daily Counts):")
display(narrative_temp_df)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3353289203> in <cell line: 0>()
#      83
#      84 # 4. Ensure the 'cleanTweet' column exists by re-cleaning if necessary
# ---> 85 if 'cleanTweet' not in tweets_df.columns:
#      86      def clean_text(text):
#      87         if pd.isna(text):
#
# NameError: name 'tweets_df' is not defined

# %% [markdown]
# **Reasoning**:
# The narrative classification was skipped because the `formatted_narratives` list was empty due to the file not being found in the previous attempt. I need to ensure the narrative CSV is correctly loaded and formatted before attempting the classification and temporal analysis again. The previous error message "Skipping narrative classification due to previous errors or empty narratives" confirms that the classification step was intentionally skipped. The current state shows that `formatted_narratives` was empty. The previous output confirms the file loading was successful with `pd.read_csv("/content/drive/MyDrive/Colab Notebooks/EleWa/Meta_narratives_in_African_elections.csv")` and no `FileNotFoundError` was printed, so the formatting step after the loading might be the issue. I need to re-run the code block, making sure that the formatting of narratives is done correctly after successful loading.

# %%
import torch
import pandas as pd
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import re
from collections import defaultdict

# 1. Re-load the narrative definitions from the CSV file and format them
try:
    narratives_df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/EleWa/Meta_narratives_in_African_elections.csv")
    formatted_narratives = []
    if not narratives_df.empty:
        for index, row in narratives_df.iterrows():
            narrative_name = row['Meta-Narrative']
            description = row['Description']
            formatted_narratives.append(f"[CLS] {narrative_name}: {description} [SEP]")
        print(f"Successfully loaded and formatted {len(formatted_narratives)} narratives.")
    else:
        print("Narratives DataFrame is empty after loading.")
        formatted_narratives = [] # Ensure it's explicitly empty if loading fails

except FileNotFoundError:
    print("Error: Narrative CSV file not found. Please ensure 'Meta_narratives_in_African_elections.csv' is in the specified path.")
    narratives_df = pd.DataFrame() # Create an empty DataFrame to avoid further errors
    formatted_narratives = [] # Ensure it's explicitly empty

# 2. Re-load the model and tokenizer for narrative classification
model_name = "distilbert-base-uncased"
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    print(f"Successfully loaded model: {model_name}")
except Exception as e:
    print(f"Error loading model or tokenizer: {e}")
    tokenizer = None
    model = None


# 3. Define the classify_tweet_narratives function
def classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model):
    """
    Classifies a tweet based on provided election-related narratives.

    Args:
        tweet: A string representing the tweet.
        formatted_narratives: A list of formatted narrative strings.
        tokenizer: The loaded tokenizer.
        model: The loaded pre-trained model.

    Returns:
        A list of predicted narrative categories.
    """
    if tokenizer is None or model is None or not formatted_narratives:
        return []

    predicted_categories = []
    for narrative in formatted_narratives:
        # Combine the tweet and narrative for the model
        combined_input = f"[CLS] {tweet} [SEP] {narrative}"

        # Tokenize the combined input
        inputs = tokenizer(combined_input, return_tensors="pt", padding=True, truncation=True, max_length=512)

        # Get model predictions
        with torch.no_grad():
            try:
                outputs = model(**inputs)
            except Exception as e:
                print(f"Error during model prediction for narrative '{narrative}': {e}")
                continue

        # Apply softmax to get probabilities
        probabilities = torch.softmax(outputs.logits, dim=1)

        # Assuming a binary classification output (e.g., [probability of not relevant, probability of relevant])
        # We are interested in the probability of the second class (relevant)
        # Check if logits has enough columns before accessing index 1
        if outputs.logits.shape[1] > 1:
            relevance_probability = probabilities[:, 1].item()
        else:
            # If the model only outputs one class, we cannot perform binary classification as intended.
            # This might indicate an issue with the model or task setup.
            print(f"Warning: Model output has only one logit ({outputs.logits.shape[1]}). Cannot perform binary classification for narrative '{narrative}'.")
            continue # Skip this narrative


        # Determine if the narrative is predicted for the tweet based on a threshold
        threshold = 0.5  # Example threshold
        if relevance_probability > threshold:
            # Extract the narrative name from the formatted string
            narrative_name = narrative.replace("[CLS] ", "").split(":")[0]
            predicted_categories.append(narrative_name.strip())

    return predicted_categories

# 4. Ensure the 'Cleaned Tweet' column exists by re-cleaning if necessary
if 'Cleaned Tweet' not in tweets_df.columns:
     def clean_text(text):
        if pd.isna(text):
            return ""
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'@\w+', '', text)
        text = re.sub(r'#\w+', '', text)
        text = re.sub(r'[^\w\s]', '', text)
        text = text.lower()
        return text
     tweets_df['Cleaned Tweet'] = tweets_df['Tweet'].apply(clean_text)
     print("Created 'Cleaned Tweet' column.")
else:
    print("'Cleaned Tweet' column already exists.")


# 5. Apply the narrative classification function to the 'Cleaned Tweet' column
if tokenizer is not None and model is not None and formatted_narratives:
    print("Starting narrative classification...")
    # Apply the classification function to each cleaned tweet
    tweets_df['Predicted Narratives'] = tweets_df['Cleaned Tweet'].apply(
        lambda tweet: classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model)
    )
    print("Narrative classification completed.")
else:
     print("Skipping narrative classification due to previous errors or empty narratives list.")
     # Ensure the column exists even if classification is skipped
     if 'Predicted Narratives' not in tweets_df.columns:
         tweets_df['Predicted Narratives'] = [[]] * len(tweets_df)


# 6. Initialize a dictionary to store narrative counts per day
narrative_daily_counts = defaultdict(lambda: defaultdict(int))

# Check if 'Day of Time' column exists and is in datetime format
if 'Day of Time' in tweets_df.columns and pd.api.types.is_datetime64_any_dtype(tweets_df['Day of Time']):
    # Iterate through each tweet
    print("Aggregating daily narrative counts...")
    for index, row in tweets_df.iterrows():
        tweet_date = row['Day of Time'].date() # Extract date
        predicted_narratives = row['Predicted Narratives']

        # For each predicted narrative in the tweet, increment the count for that date
        for narrative in predicted_narratives:
            narrative_daily_counts[narrative][tweet_date] += 1
    print("Daily narrative counts aggregated.")
else:
    print("Error: 'Day of Time' column not found or not in datetime format. Cannot perform temporal analysis.")


# 7. Convert the nested dictionary to a pandas DataFrame for easier analysis
narrative_temporal_df = pd.DataFrame.from_dict(narrative_daily_counts, orient='index').transpose().fillna(0)

# 8. Sort by date
narrative_temporal_df.sort_index(inplace=True)

# 9. Analyze for peaks (periods of increased discussion)
print("\nNarrative Temporal Analysis - Peaks:")
if not narrative_temporal_df.empty:
    for narrative in narrative_temporal_df.columns:
        if narrative_temporal_df[narrative].sum() > 0:
            max_count_date = narrative_temporal_df[narrative].idxmax()
            max_count = narrative_temporal_df[narrative].max()
            print(f"- '{narrative}': Peak activity of {int(max_count)} occurrences on {max_count_date.strftime('%Y-%m-%d')}")
        else:
            print(f"- '{narrative}': No activity recorded.")
else:
    print("Narrative temporal DataFrame is empty. Cannot analyze peaks.")


# 10. Analyze for emergence dates (first occurrence)
print("\nNarrative Temporal Analysis - Emergence Dates:")
if not narrative_temporal_df.empty:
    for narrative in narrative_temporal_df.columns:
         if narrative_temporal_df[narrative].sum() > 0:
            # Find the first date where the count is greater than 0
            emergence_date = narrative_temporal_df[narrative][narrative_temporal_df[narrative] > 0].index.min()
            if pd.notna(emergence_date):
                print(f"- '{narrative}': First occurrence on {emergence_date.strftime('%Y-%m-%d')}")
            else:
                print(f"- '{narrative}': No occurrence recorded with count > 0.")
         else:
            print(f"- '{narrative}': No activity recorded.")
else:
    print("Narrative DataFrame is empty. Cannot analyze emergence dates.")


# 11. Display the narrative temporal DataFrame
print("\nNarrative DataFrame (Daily Counts):")
display(narrative_temporal_df)
# Out:
# Successfully loaded and formatted 9 narratives.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Successfully loaded model: distilbert-base-uncased
# 'Cleaned Tweet' column already exists.
# Starting narrative classification...
# Narrative classification completed.
# Aggregating daily narrative counts...
# Daily narrative counts aggregated.
#
# Narrative Temporal Analysis - Peaks:
# - 'Foreign Interference / Neocolonialism': Peak activity of 8 occurrences on 2022-09-30
# - 'Rigged Elections / Stolen Mandate': Peak activity of 10 occurrences on 2022-09-30
# - 'Tech Manipulation Narratives': Peak activity of 8 occurrences on 2022-09-30
# - 'Ethnic / Religious Polarisation': Peak activity of 9 occurrences on 2022-09-30
# - 'Coup or Military Narratives': Peak activity of 8 occurrences on 2022-09-30
# - 'Divine / Prophetic Endorsements': Peak activity of 10 occurrences on 2022-09-30
# - 'Fake Polls and Media Clones': Peak activity of 8 occurrences on 2022-09-30
# - 'Populist “Clean Outsider” Narratives': Peak activity of 8 occurrences on 2022-09-30
# - 'Youth Disenfranchisement Claims': Peak activity of 6 occurrences on 2022-09-30
#
# Narrative Temporal Analysis - Emergence Dates:
# - 'Foreign Interference / Neocolonialism': First occurrence on 2022-09-30
# - 'Rigged Elections / Stolen Mandate': First occurrence on 2022-09-30
# - 'Tech Manipulation Narratives': First occurrence on 2022-09-30
# - 'Ethnic / Religious Polarisation': First occurrence on 2022-09-30
# - 'Coup or Military Narratives': First occurrence on 2022-09-30
# - 'Divine / Prophetic Endorsements': First occurrence on 2022-09-30
# - 'Fake Polls and Media Clones': First occurrence on 2022-09-30
# - 'Populist “Clean Outsider” Narratives': First occurrence on 2022-09-30
# - 'Youth Disenfranchisement Claims': First occurrence on 2022-09-30
#
# Narrative Temporal DataFrame (Daily Counts):
#             Foreign Interference / Neocolonialism  \
# 2022-09-30                                    8.0
# 2022-10-01                                    7.0
# 2022-10-02                                    2.0
# 2022-10-03                                    2.0
# 2022-10-04                                    2.0
# 2022-10-05                                    0.0
# 2022-10-06                                    4.0
# 2022-10-07                                    1.0
# 2022-10-08                                    2.0
# 2022-10-09                                    0.0
# 2022-10-10                                    4.0
# 2022-10-11                                    5.0
# 2022-10-12                                    2.0
# 2022-10-13                                    1.0
# 2022-10-14                                    1.0
# 2022-10-15                                    1.0
#
#             Rigged Elections / Stolen Mandate  Tech Manipulation Narratives  \
# 2022-09-30                               10.0                           8.0
# 2022-10-01                                8.0                           7.0
# 2022-10-02                                2.0                           1.0
# 2022-10-03                                3.0                           3.0
# 2022-10-04                                3.0                           1.0
# 2022-10-05                                1.0                           0.0
# 2022-10-06                                4.0                           4.0
# 2022-10-07                                1.0                           1.0
# 2022-10-08                                4.0                           3.0
# 2022-10-09                                3.0                           0.0
# 2022-10-10                                8.0                           4.0
# 2022-10-11                                5.0                           5.0
# 2022-10-12                                8.0                           3.0
# 2022-10-13                                1.0                           1.0
# 2022-10-14                                1.0                           1.0
# 2022-10-15                                1.0                           1.0
#
#             Ethnic / Religious Polarisation  Coup or Military Narratives  \
# 2022-09-30                              9.0                          8.0
# 2022-10-01                              7.0                          4.0
# 2022-10-02                              2.0                          0.0
# 2022-10-03                              3.0                          1.0
# 2022-10-04                              3.0                          1.0
# 2022-10-05                              1.0                          0.0
# 2022-10-06                              4.0                          4.0
# 2022-10-07                              1.0                          1.0
# 2022-10-08                              4.0                          2.0
# 2022-10-09                              1.0                          0.0
# 2022-10-10                              5.0                          3.0
# 2022-10-11                              5.0                          5.0
# 2022-10-12                              8.0                          1.0
# 2022-10-13                              1.0                          0.0
# 2022-10-14                              1.0                          1.0
# 2022-10-15                              1.0                          0.0
#
#             Divine / Prophetic Endorsements  Fake Polls and Media Clones  \
# 2022-09-30                             10.0                          8.0
# 2022-10-01                              8.0                          7.0
# 2022-10-02                              2.0                          2.0
# 2022-10-03                              3.0                          3.0
# 2022-10-04                              4.0                          3.0
# 2022-10-05                              1.0                          0.0
# 2022-10-06                              4.0                          4.0
# 2022-10-07                              1.0                          1.0
# 2022-10-08                              5.0                          4.0
# 2022-10-09                              3.0                          2.0
# 2022-10-10                              8.0                          4.0
# 2022-10-11                              5.0                          5.0
# 2022-10-12                              8.0                          3.0
# 2022-10-13                              1.0                          1.0
# 2022-10-14                              1.0                          1.0
# 2022-10-15                              1.0                          1.0
#
#             Populist “Clean Outsider” Narratives  \
# 2022-09-30                                   8.0
# 2022-10-01                                   7.0
# 2022-10-02                                   1.0
# 2022-10-03                                   3.0
# 2022-10-04                                   2.0
# 2022-10-05                                   0.0
# 2022-10-06                                   4.0
# 2022-10-07                                   1.0
# 2022-10-08                                   2.0
# 2022-10-09                                   1.0
# 2022-10-10                                   5.0
# 2022-10-11                                   5.0
# 2022-10-12                                   3.0
# 2022-10-13                                   1.0
# 2022-10-14                                   1.0
# 2022-10-15                                   1.0
#
#             Youth Disenfranchisement Claims
# 2022-09-30                              6.0
# 2022-10-01                              4.0
# 2022-10-02                              0.0
# 2022-10-03                              1.0
# 2022-10-04                              1.0
# 2022-10-05                              0.0
# 2022-10-06                              2.0
# 2022-10-07                              1.0
# 2022-10-08                              2.0
# 2022-10-09                              0.0
# 2022-10-10                              2.0
# 2022-10-11                              4.0
# 2022-10-12                              2.0
# 2022-10-13                              1.0
# 2022-10-14                              1.0
# 2022-10-15                              1.0

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the narrative CSV file was not found at the specified path, resulting in an empty `formatted_narratives` list and skipping the classification and temporal analysis. I need to correct the file path for the narrative CSV to ensure it is loaded correctly. I will then re-run the entire process of loading narratives, formatting them, loading the model, classifying tweets, calculating daily counts, and performing the temporal analysis. I will use the correct file path "/content/drive/MyDrive/Colab Notebooks/EleWa/Meta_narratives_in_African_elections.csv" which was confirmed in a previous successful step.

# %%
import torch
import pandas as pd
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import re
from collections import defaultdict

# 1. Load the narrative definitions from the CSV file and format them
narrative_csv_path = "/content/drive/MyDrive/ColabNotebooks/EleWa/Meta_narratives_in_African_elections.csv"
try:
    narratives_df = pd.read_csv(narrative_csv_path)
    formatted_narratives = []
    if not narratives_df.empty:
        for index, row in narratives_df.iterrows():
            narrative_name = row['Meta-Narrative']
            description = row['Description']
            formatted_narratives.append(f"[CLS] {narrative_name}: {description} [SEP]")
        print(f"Successfully loaded and formatted {len(formatted_narratives)} narratives from {narrative_csv_path}")
    else:
        print(f"Narratives DataFrame is empty after loading from {narrative_csv_path}.")
        formatted_narratives = []

except FileNotFoundError:
    print(f"Error: Narrative CSV file not found at {narrative_csv_path}. Please ensure the path is correct.")
    narratives_df = pd.DataFrame()
    formatted_narratives = []

# 2. Load the model and tokenizer for narrative classification
model_name = "distilbert-base-uncased"
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    print(f"Successfully loaded model: {model_name}")
except Exception as e:
    print(f"Error loading model or tokenizer: {e}")
    tokenizer = None
    model = None

# 3. Define the classify_tweet_narratives function
def classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model):
    """
    Classifies a tweet based on provided election-related narratives.

    Args:
        tweet: A string representing the tweet.
        formatted_narratives: A list of formatted narrative strings.
        tokenizer: The loaded tokenizer.
        model: The loaded pre-trained model.

    Returns:
        A list of predicted narrative categories.
    """
    if tokenizer is None or model is None or not formatted_narratives:
        return []

    predicted_categories = []
    for narrative in formatted_narratives:
        combined_input = f"[CLS] {tweet} [SEP] {narrative}"
        inputs = tokenizer(combined_input, return_tensors="pt", padding=True, truncation=True, max_length=512)

        with torch.no_grad():
            try:
                outputs = model(**inputs)
            except Exception as e:
                print(f"Error during model prediction for narrative '{narrative}': {e}")
                continue

        probabilities = torch.softmax(outputs.logits, dim=1)

        if outputs.logits.shape[1] > 1:
            relevance_probability = probabilities[:, 1].item()
        else:
            # print(f"Warning: Model output has only one logit ({outputs.logits.shape[1]}). Cannot perform binary classification for narrative '{narrative}'.")
            continue

        threshold = 0.5
        if relevance_probability > threshold:
            narrative_name = narrative.replace("[CLS] ", "").split(":")[0]
            predicted_categories.append(narrative_name.strip())

    return predicted_categories

# 4. Ensure the 'Cleaned Tweet' column exists by re-cleaning if necessary
if 'Cleaned Tweet' not in tweets_df.columns:
     def clean_text(text):
        if pd.isna(text):
            return ""
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'@\w+', '', text)
        text = re.sub(r'#\w+', '', text)
        text = re.sub(r'[^\w\s]', '', text)
        text = text.lower()
        return text
     tweets_df['Cleaned Tweet'] = tweets_df['Tweet'].apply(clean_text)
     print("Created 'Cleaned Tweet' column.")
else:
    print("'Cleaned Tweet' column already exists.")

# 5. Apply the narrative classification function to the 'Cleaned Tweet' column
if tokenizer is not None and model is not None and formatted_narratives:
    print("Starting narrative classification...")
    tweets_df['Predicted Narratives'] = tweets_df['Cleaned Tweet'].apply(
        lambda tweet: classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model)
    )
    print("Narrative classification completed.")
else:
     print("Skipping narrative classification due to previous errors or empty narratives list.")
     if 'Predicted Narratives' not in tweets_df.columns:
         tweets_df['Predicted Narratives'] = [[]] * len(tweets_df)

# 6. Initialize a dictionary to store narrative counts per day
narrative_daily_counts = defaultdict(lambda: defaultdict(int))

# Check if 'Day of Time' column exists and is in datetime format
if 'Day of Time' in tweets_df.columns and pd.api.types.is_datetime64_any_dtype(tweets_df['Day of Time']):
    print("Aggregating daily narrative counts...")
    for index, row in tweets_df.iterrows():
        tweet_date = row['Day of Time'].date()
        predicted_narratives = row['Predicted Narratives']

        for narrative in predicted_narratives:
            narrative_daily_counts[narrative][tweet_date] += 1
    print("Daily narrative counts aggregated.")
else:
    print("Error: 'Day of Time' column not found or not in datetime format. Cannot perform temporal analysis.")

# 7. Convert the nested dictionary to a pandas DataFrame
narrative_temporal_df = pd.DataFrame.from_dict(narrative_daily_counts, orient='index').transpose().fillna(0)

# 8. Sort by date
narrative_temporal_df.sort_index(inplace=True)

# 9. Analyze for peaks
print("\nNarrative Temporal Analysis - Peaks:")
if not narrative_temporal_df.empty:
    for narrative in narrative_temporal_df.columns:
        if narrative_temporal_df[narrative].sum() > 0:
            max_count_date = narrative_temporal_df[narrative].idxmax()
            max_count = narrative_temporal_df[narrative].max()
            print(f"- '{narrative}': Peak activity of {int(max_count)} occurrences on {max_count_date.strftime('%Y-%m-%d')}")
        else:
            print(f"- '{narrative}': No activity recorded.")
else:
    print("Narrative temporal DataFrame is empty. Cannot analyze peaks.")

# 10. Analyze for emergence dates
print("\nNarrative Temporal Analysis - Emergence Dates:")
if not narrative_temporal_df.empty:
    for narrative in narrative_temporal_df.columns:
         if narrative_temporal_df[narrative].sum() > 0:
            emergence_date = narrative_temporal_df[narrative][narrative_temporal_df[narrative] > 0].index.min()
            if pd.notna(emergence_date):
                print(f"- '{narrative}': First occurrence on {emergence_date.strftime('%Y-%m-%d')}")
            else:
                print(f"- '{narrative}': No occurrence recorded with count > 0.")
         else:
            print(f"- '{narrative}': No activity recorded.")
else:
    print("Narrative temporal DataFrame is empty. Cannot analyze emergence dates.")

# 11. Display the narrative temporal DataFrame
print("\nNarrative Temporal DataFrame (Daily Counts):")
display(narrative_temporal_df)
# Out:
# Error: Narrative CSV file not found at /content/drive/MyDrive/Colab Notebooks/EleWa/Meta_narratives_in_African_elections.csv. Please ensure the path is correct.
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Successfully loaded model: distilbert-base-uncased
# 'Cleaned Tweet' column already exists.
# Skipping narrative classification due to previous errors or empty narratives list.
# Aggregating daily narrative counts...
# Daily narrative counts aggregated.
#
# Narrative Temporal Analysis - Peaks:
# - 'Foreign Interference / Neocolonialism': Peak activity of 8 occurrences on 2022-09-30
# - 'Rigged Elections / Stolen Mandate': Peak activity of 10 occurrences on 2022-09-30
# - 'Tech Manipulation Narratives': Peak activity of 8 occurrences on 2022-09-30
# - 'Ethnic / Religious Polarisation': Peak activity of 9 occurrences on 2022-09-30
# - 'Coup or Military Narratives': Peak activity of 8 occurrences on 2022-09-30
# - 'Divine / Prophetic Endorsements': Peak activity of 10 occurrences on 2022-09-30
# - 'Fake Polls and Media Clones': Peak activity of 8 occurrences on 2022-09-30
# - 'Populist “Clean Outsider” Narratives': Peak activity of 8 occurrences on 2022-09-30
# - 'Youth Disenfranchisement Claims': Peak activity of 6 occurrences on 2022-09-30
#
# Narrative Temporal Analysis - Emergence Dates:
# - 'Foreign Interference / Neocolonialism': First occurrence on 2022-09-30
# - 'Rigged Elections / Stolen Mandate': First occurrence on 2022-09-30
# - 'Tech Manipulation Narratives': First occurrence on 2022-09-30
# - 'Ethnic / Religious Polarisation': First occurrence on 2022-09-30
# - 'Coup or Military Narratives': First occurrence on 2022-09-30
# - 'Divine / Prophetic Endorsements': First occurrence on 2022-09-30
# - 'Fake Polls and Media Clones': First occurrence on 2022-09-30
# - 'Populist “Clean Outsider” Narratives': First occurrence on 2022-09-30
# - 'Youth Disenfranchisement Claims': First occurrence on 2022-09-30
#
# Narrative Temporal DataFrame (Daily Counts):
#             Foreign Interference / Neocolonialism  \
# 2022-09-30                                    8.0
# 2022-10-01                                    7.0
# 2022-10-02                                    2.0
# 2022-10-03                                    2.0
# 2022-10-04                                    2.0
# 2022-10-05                                    0.0
# 2022-10-06                                    4.0
# 2022-10-07                                    1.0
# 2022-10-08                                    2.0
# 2022-10-09                                    0.0
# 2022-10-10                                    4.0
# 2022-10-11                                    5.0
# 2022-10-12                                    2.0
# 2022-10-13                                    1.0
# 2022-10-14                                    1.0
# 2022-10-15                                    1.0
#
#             Rigged Elections / Stolen Mandate  Tech Manipulation Narratives  \
# 2022-09-30                               10.0                           8.0
# 2022-10-01                                8.0                           7.0
# 2022-10-02                                2.0                           1.0
# 2022-10-03                                3.0                           3.0
# 2022-10-04                                3.0                           1.0
# 2022-10-05                                1.0                           0.0
# 2022-10-06                                4.0                           4.0
# 2022-10-07                                1.0                           1.0
# 2022-10-08                                4.0                           3.0
# 2022-10-09                                3.0                           0.0
# 2022-10-10                                8.0                           4.0
# 2022-10-11                                5.0                           5.0
# 2022-10-12                                8.0                           3.0
# 2022-10-13                                1.0                           1.0
# 2022-10-14                                1.0                           1.0
# 2022-10-15                                1.0                           1.0
#
#             Ethnic / Religious Polarisation  Coup or Military Narratives  \
# 2022-09-30                              9.0                          8.0
# 2022-10-01                              7.0                          4.0
# 2022-10-02                              2.0                          0.0
# 2022-10-03                              3.0                          1.0
# 2022-10-04                              3.0                          1.0
# 2022-10-05                              1.0                          0.0
# 2022-10-06                              4.0                          4.0
# 2022-10-07                              1.0                          1.0
# 2022-10-08                              4.0                          2.0
# 2022-10-09                              1.0                          0.0
# 2022-10-10                              5.0                          3.0
# 2022-10-11                              5.0                          5.0
# 2022-10-12                              8.0                          1.0
# 2022-10-13                              1.0                          0.0
# 2022-10-14                              1.0                          1.0
# 2022-10-15                              1.0                          0.0
#
#             Divine / Prophetic Endorsements  Fake Polls and Media Clones  \
# 2022-09-30                             10.0                          8.0
# 2022-10-01                              8.0                          7.0
# 2022-10-02                              2.0                          2.0
# 2022-10-03                              3.0                          3.0
# 2022-10-04                              4.0                          3.0
# 2022-10-05                              1.0                          0.0
# 2022-10-06                              4.0                          4.0
# 2022-10-07                              1.0                          1.0
# 2022-10-08                              5.0                          4.0
# 2022-10-09                              3.0                          2.0
# 2022-10-10                              8.0                          4.0
# 2022-10-11                              5.0                          5.0
# 2022-10-12                              8.0                          3.0
# 2022-10-13                              1.0                          1.0
# 2022-10-14                              1.0                          1.0
# 2022-10-15                              1.0                          1.0
#
#             Populist “Clean Outsider” Narratives  \
# 2022-09-30                                   8.0
# 2022-10-01                                   7.0
# 2022-10-02                                   1.0
# 2022-10-03                                   3.0
# 2022-10-04                                   2.0
# 2022-10-05                                   0.0
# 2022-10-06                                   4.0
# 2022-10-07                                   1.0
# 2022-10-08                                   2.0
# 2022-10-09                                   1.0
# 2022-10-10                                   5.0
# 2022-10-11                                   5.0
# 2022-10-12                                   3.0
# 2022-10-13                                   1.0
# 2022-10-14                                   1.0
# 2022-10-15                                   1.0
#
#             Youth Disenfranchisement Claims
# 2022-09-30                              6.0
# 2022-10-01                              4.0
# 2022-10-02                              0.0
# 2022-10-03                              1.0
# 2022-10-04                              1.0
# 2022-10-05                              0.0
# 2022-10-06                              2.0
# 2022-10-07                              1.0
# 2022-10-08                              2.0
# 2022-10-09                              0.0
# 2022-10-10                              2.0
# 2022-10-11                              4.0
# 2022-10-12                              2.0
# 2022-10-13                              1.0
# 2022-10-14                              1.0
# 2022-10-15                              1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# narrative_temporal_df['Foreign Interference / Neocolonialism'].plot(kind='hist', bins=20, title='Foreign Interference / Neocolonialism')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df['Rigged Elections / Stolen Mandate'].plot(kind='hist', bins=20, title='Rigged Elections / Stolen Mandate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df['Tech Manipulation Narratives'].plot(kind='hist', bins=20, title='Tech Manipulation Narratives')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df['Ethnic / Religious Polarisation'].plot(kind='hist', bins=20, title='Ethnic / Religious Polarisation')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# narrative_temporal_df.plot(kind='scatter', x='Foreign Interference / Neocolonialism', y='Rigged Elections / Stolen Mandate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df.plot(kind='scatter', x='Rigged Elections / Stolen Mandate', y='Tech Manipulation Narratives', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df.plot(kind='scatter', x='Tech Manipulation Narratives', y='Ethnic / Religious Polarisation', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df.plot(kind='scatter', x='Ethnic / Religious Polarisation', y='Coup or Military Narratives', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Rigged Elections / Stolen Mandate']
#   ys = series['Foreign Interference / Neocolonialism']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = narrative_temporal_df.sort_values('Rigged Elections / Stolen Mandate', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Rigged Elections / Stolen Mandate')
# _ = plt.ylabel('Foreign Interference / Neocolonialism')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Rigged Elections / Stolen Mandate']
#   ys = series['Tech Manipulation Narratives']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = narrative_temporal_df.sort_values('Rigged Elections / Stolen Mandate', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Rigged Elections / Stolen Mandate')
# _ = plt.ylabel('Tech Manipulation Narratives')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Rigged Elections / Stolen Mandate']
#   ys = series['Ethnic / Religious Polarisation']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = narrative_temporal_df.sort_values('Rigged Elections / Stolen Mandate', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Rigged Elections / Stolen Mandate')
# _ = plt.ylabel('Ethnic / Religious Polarisation')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Rigged Elections / Stolen Mandate']
#   ys = series['Coup or Military Narratives']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = narrative_temporal_df.sort_values('Rigged Elections / Stolen Mandate', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Rigged Elections / Stolen Mandate')
# _ = plt.ylabel('Coup or Military Narratives')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# narrative_temporal_df['Foreign Interference / Neocolonialism'].plot(kind='line', figsize=(8, 4), title='Foreign Interference / Neocolonialism')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df['Rigged Elections / Stolen Mandate'].plot(kind='line', figsize=(8, 4), title='Rigged Elections / Stolen Mandate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df['Tech Manipulation Narratives'].plot(kind='line', figsize=(8, 4), title='Tech Manipulation Narratives')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# narrative_temporal_df['Ethnic / Religious Polarisation'].plot(kind='line', figsize=(8, 4), title='Ethnic / Religious Polarisation')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
narrative_temporal_df['Foreign Interference / Neocolonialism'].plot(kind='hist', bins=20, title='Foreign Interference / Neocolonialism')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Identify Connections/Associations
#
# ### Subtask:
# Identify relationships and connections between extracted actors, classified narratives, and temporal information to understand the network of influence and information flow.

# %% [markdown]
# **Reasoning**:
# Re-run the actor extraction and narrative classification steps to ensure the necessary columns ('Extracted Actors' and 'Predicted Narratives') are available. Then, implement a method to identify connections based on co-occurrence within tweets, linking actors, narratives, and timelines to build a connection list.

# %%
from transformers import pipeline
import pandas as pd
import re
import torch
from collections import defaultdict

# Ensure the 'Cleaned Tweet' column exists by re-cleaning if necessary
if 'Cleaned Tweet' not in tweets_df.columns:
     def clean_text(text):
        if pd.isna(text):
            return ""
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'@\w+', '', text)
        text = re.sub(r'#\w+', '', text)
        text = re.sub(r'[^\w\s]', '', text)
        text = text.lower()
        return text
     tweets_df['Cleaned Tweet'] = tweets_df['Tweet'].apply(clean_text)
     print("Created 'Cleaned Tweet' column.")
else:
    print("'Cleaned Tweet' column already exists.")


# Re-run Actor Extraction (NER)
# Create a named entity recognition (NER) pipeline
# Using a suitable pre-trained model (e.g., "dslim/bert-base-NER")
# Ensure the model is loaded only once if possible
if 'ner_pipeline' not in locals():
    try:
        ner_pipeline = pipeline("ner", model="dslim/bert-base-NER", grouped_entities=True)
        print("Successfully loaded NER pipeline.")
    except Exception as e:
        print(f"Error loading NER pipeline: {e}")
        ner_pipeline = None

def extract_entities(text):
    """
    Extracts named entities from the input text using the NER pipeline.
    """
    if ner_pipeline is None or pd.isna(text):
        return []
    try:
        entities = ner_pipeline(text)
        # Extract only the entity text and type
        extracted_list = [{'entity': entity['word'], 'type': entity['entity_group']} for entity in entities]
        return extracted_list
    except Exception as e:
        print(f"Error during entity extraction for text: {text[:50]}... Error: {e}")
        return []


# Apply the function to the 'Cleaned Tweet' column
if ner_pipeline is not None:
    print("Starting actor extraction...")
    tweets_df['Extracted Actors'] = tweets_df['Cleaned Tweet'].apply(extract_entities)
    print("Actor extraction completed.")
else:
    print("Skipping actor extraction due to NER pipeline loading error.")
    if 'Extracted Actors' not in tweets_df.columns:
        tweets_df['Extracted Actors'] = [[]] * len(tweets_df)


# Re-run Narrative Classification
# Load the narratives from the CSV and format them
narrative_csv_path = "/content/drive/MyDrive/ColabNotebooks/EleWa/Meta_narratives_in_African_elections.csv"
try:
    narratives_df = pd.read_csv(narrative_csv_path)
    formatted_narratives = []
    if not narratives_df.empty:
        for index, row in narratives_df.iterrows():
            narrative_name = row['Meta-Narrative']
            description = row['Description']
            formatted_narratives.append(f"[CLS] {narrative_name}: {description} [SEP]")
        print(f"Successfully loaded and formatted {len(formatted_narratives)} narratives from {narrative_csv_path}")
    else:
        print(f"Narratives DataFrame is empty after loading from {narrative_csv_path}.")
        formatted_narratives = []

except FileNotFoundError:
    print(f"Error: Narrative CSV file not found at {narrative_csv_path}. Please ensure the path is correct.")
    narratives_df = pd.DataFrame()
    formatted_narratives = []

# Re-load the model and tokenizer for narrative classification
model_name = "distilbert-base-uncased"
if 'tokenizer' not in locals() or 'model' not in locals():
    try:
        tokenizer = AutoTokenizer.from_pretrained(model_name)
        model = AutoModelForSequenceClassification.from_pretrained(model_name)
        print(f"Successfully loaded model: {model_name}")
    except Exception as e:
        print(f"Error loading model or tokenizer: {e}")
        tokenizer = None
        model = None

def classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model):
    """
    Classifies a tweet based on provided election-related narratives.

    Args:
        tweet: A string representing the tweet.
        formatted_narratives: A list of formatted narrative strings.
        tokenizer: The loaded tokenizer.
        model: The loaded pre-trained model.

    Returns:
        A list of predicted narrative categories.
    """
    if tokenizer is None or model is None or not formatted_narratives:
        return []

    predicted_categories = []
    for narrative in formatted_narratives:
        combined_input = f"[CLS] {tweet} [SEP] {narrative}"
        inputs = tokenizer(combined_input, return_tensors="pt", padding=True, truncation=True, max_length=512)

        with torch.no_grad():
            try:
                outputs = model(**inputs)
            except Exception as e:
                print(f"Error during model prediction for narrative '{narrative}': {e}")
                continue

        probabilities = torch.softmax(outputs.logits, dim=1)

        if outputs.logits.shape[1] > 1:
            relevance_probability = probabilities[:, 1].item()
        else:
            # print(f"Warning: Model output has only one logit ({outputs.logits.shape[1]}). Cannot perform binary classification for narrative '{narrative}'.")
            continue

        threshold = 0.5
        if relevance_probability > threshold:
            narrative_name = narrative.replace("[CLS] ", "").split(":")[0]
            predicted_categories.append(narrative_name.strip())

    return predicted_categories

# Apply the narrative classification function to the 'Cleaned Tweet' column
if tokenizer is not None and model is not None and formatted_narratives:
    print("Starting narrative classification...")
    tweets_df['Predicted Narratives'] = tweets_df['Cleaned Tweet'].apply(
        lambda tweet: classify_tweet_narratives(tweet, formatted_narratives, tokenizer, model)
    )
    print("Narrative classification completed.")
else:
     print("Skipping narrative classification due to previous errors or empty narratives list.")
     if 'Predicted Narratives' not in tweets_df.columns:
         tweets_df['Predicted Narratives'] = [[]] * len(tweets_df)


# Re-run Temporal Extraction (if needed for connections)
# This step was confirmed to be working previously, but including it here
# to ensure all necessary columns are present before identifying connections.
def extract_timelines(text):
    """
    Extracts temporal information (dates, times, events) from the input text.
    (Using simplified regex for now)
    """
    if pd.isna(text):
        return []

    temporal_info = []

    # Basic regex for common date formats (MM/DD/YYYY, YYYY-MM-DD, DD-MM-YYYY, etc.)
    date_patterns = [
        r'\d{1,2}/\d{1,2}/\d{2,4}',
        r'\d{4}-\d{1,2}-\d{1,2}',
        r'\d{1,2}-\d{1,2}-\d{4}',
        r'\b(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\s+\d{1,2}(?:,\s*\d{4})?\b',
        r'\d{1,2}\s+(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)(?:,\s*\d{4})?\b'
    ]

    # Basic regex for common time formats (HH:MM, HH:MM:SS, HH AM/PM)
    time_patterns = [
        r'\d{1,2}:\d{2}(?::\d{2})?(?:\s?(?:AM|PM))?'
    ]

    # Combine patterns
    all_patterns = date_patterns + time_patterns

    for pattern in all_patterns:
        matches = re.findall(pattern, text, re.IGNORECASE)
        temporal_info.extend(matches)


    return list(set(temporal_info)) # Return unique findings

# Apply the function to the 'Cleaned Tweet' column
if 'Extracted Timelines' not in tweets_df.columns:
    print("Starting temporal information extraction...")
    tweets_df['Extracted Timelines'] = tweets_df['Cleaned Tweet'].apply(extract_timelines)
    print("Temporal information extraction completed.")
else:
    print("'Extracted Timelines' column already exists.")


# Now, identify connections/associations based on co-occurrence
def identify_connections(row):
    """
    Identifies connections between extracted actors, narratives, and timelines
    within a single tweet based on co-occurrence.
    """
    connections = []
    # Ensure the columns exist before accessing them, use .get() for safer access
    tweet_id = row.get('Tweet ID')
    actors = [entity['entity'] for entity in row.get('Extracted Actors', [])]
    narratives = row.get('Predicted Narratives', [])
    timelines = row.get('Extracted Timelines', [])


    # Find co-occurrences
    # Connections between actors and narratives
    for actor in actors:
        for narrative in narratives:
             # Include tweet_id in connections for traceability
            connections.append({'source': actor, 'target': narrative, 'type': 'actor-narrative', 'tweet_id': tweet_id})

    # Connections between actors and timelines
    for actor in actors:
        for timeline in timelines:
             # Include tweet_id in connections for traceability
            connections.append({'source': actor, 'target': timeline, 'type': 'actor-timeline', 'tweet_id': tweet_id})

    # Connections between narratives and timelines
    for narrative in narratives:
        for timeline in timelines:
             # Include tweet_id in connections for traceability
            connections.append({'source': narrative, 'target': timeline, 'type': 'narrative-timeline', 'tweet_id': tweet_id})

    # Add connections based on retweets
    # This part requires linking retweets back to the original tweet or actor.
    # Using 'RetweetUser' from tweets_df as a proxy for the original author of a retweeted tweet
    if 'RetweetUser' in row and pd.notna(row['RetweetUser']) and tweet_id is not None:
         # Find the retweeter(s) for this tweet ID from the retweets_df
         # Ensure 'Tweet ID' column exists in retweets_df and filter
         if 'Tweet ID' in retweets_df.columns:
             retweeters_for_tweet = retweets_df[retweets_df['Tweet ID'] == tweet_id]['Twitter Users'].tolist()
             original_author = row['RetweetUser']
             for retweeter in retweeters_for_tweet:
                 if retweeter != original_author: # Avoid self-loops
                     connections.append({'source': retweeter, 'target': original_author, 'type': 'retweet', 'tweet_id': tweet_id})
         else:
             print(f"Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID {tweet_id}.")


    return connections

# Apply the function to each row of the DataFrame to identify connections
print("Starting connection identification...")
tweets_df['Extracted Connections'] = tweets_df.apply(identify_connections, axis=1)
print("Connection identification completed.")

# Display the head of the DataFrame showing the relevant columns
display(tweets_df[['Cleaned Tweet', 'Extracted Actors', 'Predicted Narratives', 'Extracted Timelines', 'Extracted Connections']].head())
# Out:
# 'Cleaned Tweet' column already exists.
# Starting actor extraction...
# Actor extraction completed.
# Successfully loaded and formatted 9 narratives from /content/drive/MyDrive/ColabNotebooks/EleWa/Meta_narratives_in_African_elections.csv
# Starting narrative classification...
# Narrative classification completed.
# 'Extracted Timelines' column already exists.
# Starting connection identification...
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579533598625240064.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578291198951030016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575938681676110080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578675313155760128.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577040372202889984.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575911139434980096.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580255633466870016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576968595052989952.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579496242367059968.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579791053502429952.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576167981700160000.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576335117823320064.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579885278843760128.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576457024212110080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576236773692539904.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580866098756430080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1581212739417959936.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576316603758579968.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577010979451239936.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579287837811229952.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579900237938030080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578780610856100096.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577445247310820096.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579159233811320064.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575694517440719872.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580242587750799872.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575849612673319936.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580641887332879872.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575898938540009984.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576377383057509888.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579790597430569984.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577784684997740032.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580200721269469952.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577504495642230016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580186072138769920.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579513848390119936.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575844720953390080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578869407849520128.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578060183661590016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576224270845639936.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579488736408399872.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580124130837260032.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579271561080880128.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577997423632310016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577961853346609920.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578140262588499968.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576219641785220096.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576316097875249920.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580000141079350016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579819405428780032.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580155107034870016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579256835470909952.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577246297135849984.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1580154233663249920.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576868800548379904.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576169134773390080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1576883029137850112.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575853368832290048.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577246117355719936.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575751755203480064.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579270529802190080.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579428064223970048.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578810942485580032.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1579152640285769984.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575748628211440128.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1577249445548189952.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575875313552150016.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1575845272164260096.
# Warning: 'Tweet ID' column not found in retweets_df. Cannot add retweet connections for Tweet ID 1578633552693929984.
# Connection identification completed.
#                                        Cleaned Tweet Extracted Actors  \
# 0  rt   on transit as a keke rider i carry more t...               []
# 1  rt   on transit as a keke rider i carry more t...               []
# 2    rt  it was nice hosting my brother  once again                []
# 3  rt  your pvc is your power have you gotten it ...               []
# 4  rt  oh dear it is never a good sign in a presi...               []
#
#                                 Predicted Narratives Extracted Timelines  \
# 0                  [Divine / Prophetic Endorsements]                  []
# 1                  [Divine / Prophetic Endorsements]                  []
# 2  [Rigged Elections / Stolen Mandate, Divine / P...                  []
# 3  [Foreign Interference / Neocolonialism, Rigged...                  []
# 4  [Foreign Interference / Neocolonialism, Rigged...                  []
#
#   Extracted Connections
# 0                    []
# 1                    []
# 2                    []
# 3                    []
# 4                    []
